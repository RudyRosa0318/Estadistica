# %%
#Rudy Rosa
import os
import pandas as pd
import matplotlib.pyplot as ptl
import numpy as np
from scipy import stats as ss

# %% [markdown]
# ## Media Aritmetica
# también llamada promedio o media, de un conjunto infinito de números es el valor característico de una serie de datos cuantitativos, objeto de estudio que parte del principio de la esperanza matemática o valor esperado, se obtiene a partir de la suma de todos sus valores dividida entre el número de sumandos.
#
#
# ![image.png](attachment:image.png)

# %%
mainpath ="/Users/Norma/Desktop/Estadistica"
filename = "faithful.csv"
fullpath = os.path.join(mainpath, filename)

# %%
data = pd.read_csv(fullpath, error_bad_lines=False)
data
# Out:
#      number  eruptions  waiting
# 0         1      3.600       79
# 1         2      1.800       54
# 2         3      3.333       74
# 3         4      2.283       62
# 4         5      4.533       85
# ..      ...        ...      ...
# 267     268      4.117       81
# 268     269      2.150       46
# 269     270      4.417       90
# 270     271      1.817       46
# 271     272      4.467       74
#
# [272 rows x 3 columns]

# %%
datos = np.random.randn(5, 4)
def media(valores):
    return sum(valores)/len(valores)

# %%
valores = (9, 123, 5, 4, 12, 45, 56, 76)
print('El promedio de ',valores,' es: ',media(valores))
# Out:
# El promedio de  (9, 123, 5, 4, 12, 45, 56, 76)  es:  41.25

# %%
#Media Aritmetica con Data set
data['eruptions'].mean()
# Out:
# 3.4877830882352936

# %% [markdown]
# ## La Mediana
# es el valor que dentro del conjunto de datos es menor que el 50% de los datos y mayor que el 50% restante.
# ![image.png](attachment:image.png)

# %%
#data set
data['eruptions'].median()
# Out:
# 4.0

# %%
#datos
datos = np.random.randn(4,5)
datos
# Out:
# array([[ 0.63206755,  0.08275462, -0.10706226,  0.56739557,  1.21409146],
#        [-1.26792504,  1.88701535,  0.06396205,  0.24812267, -0.70973025],
#        [-1.36775185, -0.22991475,  1.67943852,  0.83793085,  1.24237756],
#        [-2.36089335,  0.4247235 , -0.58718443,  0.5673617 ,  0.20584387]])

# %%
np.median(datos)
# Out:
# 0.22698326717328

# %% [markdown]
# ## La moda
# es el valor que tiene mayor frecuencia absoluta. Se representa con M0
# ![image.png](attachment:image.png)

# %%
#Datos
stats.mode(datos)
# Out:
# ModeResult(mode=array([[-2.36089335, -0.22991475, -0.58718443,  0.24812267, -0.70973025]]), count=array([[1, 1, 1, 1, 1]]))

# %%
datos2 = np.array([1, 2, 3, 6, 6, 1, 2, 4, 2, 2, 6, 6, 8, 10, 6])
stats.mode(datos2)
# Out:
# ModeResult(mode=array([6]), count=array([5]))

# %%
#data set
data['eruptions'].mode()
# Out:
# 0    1.867
# 1    4.500
# dtype: float64

# %% [markdown]
# ## Percenties
# una medida de posición usada en estadística que indica, una vez ordenados los datos de menor a mayor, el valor de la variable por debajo del cual se encuentra un porcentaje dado de observaciones en un grupo.
# ![image.png](attachment:image.png)

# %%
#Datos
percent = np.percentile(datos,20)
percent
# Out:
# -0.6116935975476986

# %%
#dataset
np.percentile(data["eruptions"],99)
# Out:
# 5.009570000000001

# %% [markdown]
# ## Varianza
# Intenta describir la dispersión de los datos. Se define como la esperanza del cuadrado de la desviación de dicha variable respecto a su media. Una varianza pequeña indica que los puntos de datos tienden a estar muy cerca de la media y por lo tanto el uno al otro, mientras que una varianza alta indica que los puntos de datos están muy distribuidos alrededor de la media y la una de la otra.
# ![image.png](attachment:image.png)

# %%
#Datos
np.var(datos)
# Out:
# 1.0473905446482379

# %%
#varianza de cada columna
np.var(datos, 0)
# Out:
# array([1.17237122, 0.65739396, 0.72641795, 0.04363247, 0.65261602])

# %%
#dataset
data['eruptions'].var()
# Out:
# 1.302728332849468

# %% [markdown]
# ## Desviacion Tipica o Estandar
#  es una medida que se utiliza para cuantificar la cantidad de variación o dispersión de un conjunto de valores de datos. Un desvío estándar cerca de 0 indica que los puntos de datos tienden a estar muy cerca de la media del conjunto, mientras que un alto desvío estándar indica que los puntos de datos se extienden a lo largo de un rango amplio de valores.
#  ![image.png](attachment:image.png)

# %%
#Datos
np.std(datos)
# Out:
# 1.0234210006875166

# %%
#Desviación típica de cada columna
np.std(datos, 0)
# Out:
# array([1.08276093, 0.81079835, 0.85230156, 0.20888386, 0.80784653])

# %%
data['eruptions'].std()
# Out:
# 1.141371251105208

# %% [markdown]
# ## Coeficiente de variación
#  una medida que sirve para comparar entre dos muestras, cuál varía más y cuál es más estable. Es una simple división, de la desviación típica sobre la media
#  ![image.png](attachment:image.png)

# %%
#data set
o = data['eruptions'].std()
u = data['eruptions'].mean()
cv = o / u
cv2 = ss.variation(data["eruptions"])
print("Manera 1 =",cv) 
print("Manera 2 =",cv2)
# Out:
# Manera 1 = 0.3272483472252586
# Manera 2 = 0.3266462338408214

# %%
#datos
o1 = np.std(datos)
u1 = np.mean(datos)
cv3 = o1/u1
cv4 = ss.variation(datos)
print("Manera 1 =",cv3) 
print("Manera 2 =",cv4)
# Out:
# Manera 1 = 6.771740223618744
# Manera 2 = [-0.99233384  1.49830235  3.24948161  0.3762299   1.65492925]

# %% [markdown]
# ## Kurtosis
# se utiliza para describir la forma de la distribución es la kurtósis o curtósis. Esta utiliza el moomento central estandarizado de orden 4 para detectar valores extremos. En presencia de valores extremos, la forma de la distribución parece más puntiaguda; por esto la kurtósis se conoce como una medida del apuntalamiento de la distribución.
#
# Dada una muestra x1,x2,...,xn, la kurtósis se calcula como
# ![image.png](attachment:image.png)
#
# Este valor lo comparamos con 3, y dependiendo de ello, decimos que la distribución es Platicúrtica, Mesocúrtica o Leptocúrtica:
#
# Si kurtosis<3 la distribución es Platicúrtica
# Si kurtosis=3 la distribución es Mesocúrtica
# Si kurtosis>3 la distribución es Leptocúrtica

# %%
datos.kurt()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-a8d449369388> in <module>
# ----> 1 datos.skew()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'skew'
